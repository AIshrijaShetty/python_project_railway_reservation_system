# %%
train= {
"Train_Number": 12951,
"Train_Name": "Mumbai Rajdhani Express",
"Source": "Mumbai",
"Destination": "Delhi",
 "Available_Seats": 120
}

# %%
print("Train Information:")
print(train)

print("\nTrain Number:", train["Train_Number"])
print("Train Name:", train["Train_Name"])
print("Source Station:", train["Source"])
print("Destination Station:", train["Destination"])
print("Available Seats:", train['Available_Seats'])
# Out:
# Train Information:
# {'Train_Number': 12951, 'Train_Name': 'Mumbai Rajdhani Express', 'Source': 'Mumbai', 'Destination': 'Delhi', 'Available_Seats': 120}
#
# Train Number: 12951
# Train Name: Mumbai Rajdhani Express
# Source Station: Mumbai
# Destination Station: Delhi
# Available Seats: 120

# %%
train={
"Train_Number": 12951,
"Train_Name": "Mumbai Rajdhani Express",
 "Available Seat": 120
        }

# %%
print(train)
# Out:
# {'Train_Number': 12951, 'Train_Name': 'Mumbai Rajdhani Express', 'Available Seat': 120}

# %%
print("Train Name:", train["Train_Name"])
print("Available Seats:", train['Available Seat'])
# Out:
# Train Name: Mumbai Rajdhani Express
# Available Seats: 120

# %%
train["Available Seats"] = 95
print(train)
# Out:
# {'Train_Number': 12951, 'Train_Name': 'Mumbai Rajdhani Express', 'Available Seat': 120, 'Available Seats': 95}

# %%
train.update({"Platform" : 4})
print(train)
# Out:
# {'Train_Number': 12951, 'Train_Name': 'Mumbai Rajdhani Express', 'Available Seat': 120, 'Available Seats': 95, 'Platform': 4}

# %%
train.pop("Platform")
print(train)
# Out:
# {'Train_Number': 12951, 'Train_Name': 'Mumbai Rajdhani Express', 'Available Seat': 120, 'Available Seats': 95}

# %%
print("\nUpdated Train Records:")
print(train)
# Out:
# Updated Train Records:
# {'Train_Number': 12951, 'Train_Name': 'Mumbai Rajdhani Express', 'Available Seat': 120, 'Available Seats': 95}
