# %% [markdown]
# Hello_World_Demo

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("I am Shrija")
# Out:
# I am Shrija

# %%
print("My Laptop is of H.P Company")
# Out:
# My Laptop is of H.P Company
