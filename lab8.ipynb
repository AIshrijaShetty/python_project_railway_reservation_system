# %%
# student={"s_id": 101,
#          "s_name": "Amit",
#          "s_marks": 56
#          }
# type(student)

# %%
passengers = ["Rahul Sharma","Priya Patel","Amit Verma"]

print("Passenger Reservation List:")
print(passengers)

print("/nFirst Passenger:",passengers[0])

print("Second Passenger:",passengers[1])

print("Third Passenger:",passengers[2])
# Out:
# Passenger Reservation List:
# ['Rahul Sharma', 'Priya Patel', 'Amit Verma']
# /nFirst Passenger: Rahul Sharma
# Second Passenger: Priya Patel
# Third Passenger: Amit Verma

# %%
print(passengers)
# Out:
# ['Rahul Sharma', 'Priya Patel', 'Amit Verma']

# %%
passengers.append("Snehal Joshi")
print(passengers)
# Out:
# ['Rahul Sharma', 'Priya Patel', 'Amit Verma', 'Snehal Joshi']

# %%
passengers.remove("Amit Verma")
print(passengers)
# Out:
# ['Rahul Sharma', 'Priya Patel', 'Snehal Joshi']

# %%
passengers.insert(1,"Rohan Mehta")
print(passengers)
# Out:
# ['Rahul Sharma', 'Rohan Mehta', 'Priya Patel', 'Snehal Joshi']

# %%
removed_passenger =  passengers.pop(2)
print(passengers)
# Out:
# ['Rahul Sharma', 'Rohan Mehta', 'Snehal Joshi']

# %%
print("\nUpdated Reservation List:")
print(passengers)
# Out:
# Updated Reservation List:
# ['Rahul Sharma', 'Rohan Mehta', 'Snehal Joshi']
